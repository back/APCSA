// %% [markdown]
// # Course Review
//
// ### Java Basics
// Primitive Types
// 	Operator Precedence
// 	Integer Division
//
// Input / Output
//
// String
// 	Escape Sequence
//
// Condition Control
//
// Exception
// "Checked exception are not in AP exam"
//
// ### Class Design
// Fields
// 	Public / Private
// 	Static
//
// Methods
// 	Constructors
// 		parameter shadowing: this
// 	Mutators
// 	Static
//
// 	Overloading
//
// Concept of reference (key to the house)
// 	null
//
// Passing reference as parameters
//
// Superclass / Subclass
// 	extends
//
// 	Overriding
// 		this / super
//
// Rules for Subclasses (p.137)
//
// Polymorphism
// 	Downcasting
// 	Late Binding
//
// ### Standard Classes
// Object class
// 	toString()
// 	equals()
//
//
// String class
//
// Wrapper classes
// 	Integer
// 	Double
// 	(Boolean)
//
// Math class
//
//
// ### Arrays
// Simple Array
//
// ArrayList
// 	(no interface requirement in 9th edition)
// 	(no iterator requirement in 9th edition)
//
// 2D Array
//
// ### Algorighms
// Recursion
// 	generic framework of recursion (p.292)
//
// 	4-way recursion (in 2D array processing)
//
// Sorting
// 	Selection sort
// 	Insertion sort
//
// 	Merge sort
// 	Quick sort
//
// Searching
// 	Sequential Search
// Binary Search
//
// ### APCSA Labs
//
// ### Lab Resources
//
//
//
// ### Program Analysis
//
// Software Development Life Cycle (SDLC)
//
// OOD / OOP / UML
//
// Top-down / Bottom-up
//
// Pre Condition / Post Condition
//
// Efficiency
// 	Time (CPU operations)
// 	Space (memory)
