// %% [markdown]
// # Recursion
//
//
// Functions calls ->
// - Suspend current Program Flow
// - Jump to a different flow
// - When returned, continues previous flow
//
//
// Example ->
// - Doing homework
//   - Go vacuum the house
//     - Take a bath
//
// Imaginary Example
// - CEO performance reports()
//   - next level manager performance report()
//   - …
//   - staff performance reports()
//
//
// Animate Example
//
// - Factorial
// - https://www.educative.io/courses/recursion-for-coding-interviews-in-python/B8wMXy0nmvk
//
// - Fibonacci
// - https://visualgo.net/en/recursion
//
//
// - Tower of Hanoi
// - http://towersofhanoi.info/Animate.aspx
//
// - Flood Fill (zombie and cats)
// - https://inventwithpython.com/blog/2011/08/11/recursion-explained-with-the-flood-fill-algorithm-and-zombies-and-cats/
//
//
// - Maze Runner
// - https://preview.redd.it/qzmfijn9kewz.gif?format=mp4&s=dfd4ed9f00c9c45eb0641be4a54a610abf212e94
//
//
// Exiting Condition ->
// - Also called: Base Case
//
//
//
// Text Book examples
// - WordPlay
// - 2-D Grid
//
// Windows Paint (Flood Filling)
//
//
//
// Palindrome String

// %% [markdown]
// Concepts
//
// A recursive method is a method that calls itself.
//
// Recursive methods contain at least one base case, which halts the recursion, and at least one recursive call.
//
//
// Each recursive call has its own set of local variables, including the formal parameters.
//
//
// Parameter values capture the progress of a recursive process, much like loop control variable values capture the progress of a loop.
//
// Any recursive solution can be replicated through the use of an iterative approach.
//
// X EXCLUSION STATEMENT—:
// - Writing recursive program code is outside the scope of the course and AP Exam.
//
//
// Recursion can be used to traverse String, array, and ArrayList objects

// %% [markdown]
// ### Homework
//
// Post Chapter Questions
// - All of them.
//
// Rune Stone
// https://runestone.academy/runestone/books/published/apcsareview/Recursion/toctree.html
//
//
// Coding Bat
// https://codingbat.com/java/Recursion-1
// https://codingbat.com/java/Recursion-2
